# %%
## IMPORT OF LIBRARIES
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## READING IN THE DATASET
df = pd.read_csv('./cleaned_student_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0     Names    Age Gender  Mobile Phone  Mobile Operating System   \
# 0           0       Ali  21-25    Male           Yes                  Android
# 1           1     Bilal  21-25    Male           Yes                  Android
# 2           2    Hammad  21-25    Male           Yes                      IOS
# 3           3  Abdullah  21-25    Male           Yes                  Android
# 4           4     Waqar  21-25    Male           Yes                      IOS
#
#   Mobile phone use for education Mobile phone activities Helpful for studying  \
# 0                      Sometimes            Social Media                  Yes
# 1                      Sometimes            Social Media                  Yes
# 2                      Sometimes            All of these                  Yes
# 3                     Frequently            All of these                  Yes
# 4                     Frequently            All of these                  Yes
#
# ...

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#       Names    Age Gender  Mobile Phone  Mobile Operating System   \
# 0       Ali  21-25    Male           Yes                  Android
# 1     Bilal  21-25    Male           Yes                  Android
# 2    Hammad  21-25    Male           Yes                      IOS
# 3  Abdullah  21-25    Male           Yes                  Android
# 4     Waqar  21-25    Male           Yes                      IOS
#
#   Mobile phone use for education Mobile phone activities Helpful for studying  \
# 0                      Sometimes            Social Media                  Yes
# 1                      Sometimes            Social Media                  Yes
# 2                      Sometimes            All of these                  Yes
# 3                     Frequently            All of these                  Yes
# 4                     Frequently            All of these                  Yes
#
#      Educational Apps Daily usages Performance impact      Usage distraction  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Names                           99 non-null     object
#  1   Age                             99 non-null     object
#  2   Gender                          99 non-null     object
#  3   Mobile Phone                    99 non-null     object
#  4   Mobile Operating System         99 non-null     object
#  5   Mobile phone use for education  99 non-null     object
#  6   Mobile phone activities         99 non-null     object
#  7   Helpful for studying            99 non-null     object
#  8   Educational Apps                99 non-null     object
#  9   Daily usages                    99 non-null     object
#  10  Performance impact              99 non-null     object
#  11  Usage distraction               99 non-null     object
# ...

# %%
df.isnull().sum()
# Out:
# Names                             0
# Age                               0
# Gender                            0
# Mobile Phone                      0
# Mobile Operating System           0
# Mobile phone use for education    0
# Mobile phone activities           0
# Helpful for studying              0
# Educational Apps                  0
# Daily usages                      0
# Performance impact                0
# Usage distraction                 0
# Attention span                    0
# Useful features                   0
# Health Risks                      0
# Beneficial subject                0
# Usage symptoms                    1
# Symptom frequency                 0
# Health precautions                0
# Health rating                     0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                                count unique                   top freq
# Names                             99     99                   Ali    1
# Age                               99      4                 21-25   71
# Gender                            99      2                  Male   81
# Mobile Phone                      99      1                   Yes   99
# Mobile Operating System           99      2               Android   80
# Mobile phone use for education    99      4             Sometimes   54
# Mobile phone activities           99      7          All of these   59
# Helpful for studying              99      2                   Yes   95
# Educational Apps                  99      4    Educational Videos   54
# Daily usages                      99      4             4-6 hours   40
# Performance impact                99      5                 Agree   40
# Usage distraction                 99      4        While Studying   34
# ...

# %%
## AGE DISTRIBUTION
plt.figure(figsize=(4,2), dpi=200)
sns.histplot(data=df, x='Age', kde=True,  color = "pink", ec="pink")
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['Names', 'Age', 'Gender ', 'Mobile Phone ', 'Mobile Operating System ',
#        'Mobile phone use for education', 'Mobile phone activities',
#        'Helpful for studying', 'Educational Apps', 'Daily usages',
#        'Performance impact', 'Usage distraction', 'Attention span',
#        'Useful features', 'Health Risks', 'Beneficial subject',
#        'Usage symptoms', 'Symptom frequency', 'Health precautions',
#        'Health rating'],
#       dtype='object')

# %%
df.rename(columns = {'Gender ':'Gender', 
                    'Mobile Phone ': 'Mobile Phone', 
                    'Mobile Operating System ': 'Mobile Operating System'}, inplace = True)

# %%
# GENDER DISTRIBUTION
sns.countplot(data=df, x='Gender', palette='pastel')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
## PERCENTAGE OF STUDENTS WHO OWN A MOBILE PHONE
students_own_mobile_phone = df['Mobile Phone'].value_counts()['Yes']
total_students = len(df)
print((students_own_mobile_phone/total_students)*100)
# Out:
# 100.0

# %%
## TYPES OF MOBILE OPERATING SYSTEMS USED BY STUDENTS

ax = sns.countplot(data=df, x='Mobile Operating System', palette='muted')
for container in ax.containers:
    ax.bar_label(container)

# %%
## DISTRIBUTION OF MOBILE PHONE USE FOR EDUCATION

mob_use_ed = sns.countplot(data=df, x='Mobile phone use for education', palette='deep')
for container in mob_use_ed.containers:
    mob_use_ed.bar_label(container)

# %%
# DISTRIBUTION OF COMMON MOBILE PHONE ACTIVITIES

sns.countplot(data=df, x='Mobile phone activities', palette='deep')
plt.xticks(rotation=90);

# %%
## DISTRIBUTION OF PARTICIPANTS WHO FIND MOBILE PHONES USEFUL FOR STUDYING 

helpful = sns.countplot(data=df, x='Helpful for studying')
for container in helpful.containers:
    helpful.bar_label(container)

# %%
# MOST FREQUENTLY USED EDUCATIONAL APPS

ed_apps = sns.countplot(data=df, x='Educational Apps', palette='deep')
plt.xticks(rotation=90);
for container in ed_apps.containers:
    ed_apps.bar_label(container)

# %%
#daily usage pattern 

sns.countplot(data=df, x='Daily usages')
# Out:
# <Axes: xlabel='Daily usages', ylabel='count'>

# %%
## How does mobile phone usage impact academic performance?

sns.countplot(data=df, x='Performance impact')
plt.xticks(rotation=90);

# %%
## Is there a significant difference in daily usage among different age groups or genders?
sns.countplot(data=df, x='Daily usages', hue='Gender')
plt.xticks(rotation=90);

# %%
## How often do participants experience distractions due to mobile phone usage?

usage_dist = sns.countplot(data=df, x='Usage distraction')
plt.xticks(rotation=90);
for container in usage_dist.containers:
    usage_dist.bar_label(container)

# %%
## What are the most commonly reported symptoms related to mobile phone usage?

sns.countplot(data=df, x='Usage symptoms')
plt.xticks(rotation = 90);

# %%
## How frequently do participants experience these symptoms?

sns.countplot(data=df, x='Symptom frequency')
plt.xticks(rotation = 90);

# %%
## What health risks are associated with mobile phone usage, according to the participants?

sns.countplot(data=df, x='Health Risks')
# Out:
# <Axes: xlabel='Health Risks', ylabel='count'>

# %%
## How do participants rate their overall health in relation to their mobile phone usage?
sns.countplot(data=df, x='Health rating')
plt.xticks(rotation=-45);

# %%
## What health precautions are taken by participants?

sns.countplot(data=df, x='Health precautions')
plt.xticks(rotation=90);

# %%
## Does mobile phone usage have a significant impact on the attention span of participants?

sns.countplot(data=df, x='Attention span')
# Out:
# <Axes: xlabel='Attention span', ylabel='count'>

# %%
## What are the useful features of mobile phones that participants believe are beneficial?

sns.countplot(data=df, x='Useful features')
# Out:
# <Axes: xlabel='Useful features', ylabel='count'>

# %%
## Which subjects or areas of study do participants find most beneficial when using mobile phones?

sns.countplot(data=df, x='Beneficial subject')
# Out:
# <Axes: xlabel='Beneficial subject', ylabel='count'>

# %%
## Is there a correlation between the amount of daily mobile phone usage and performance impact?

## CHI-SQUARE TEST IS USED TO TEST THE RELATIONSHIP BETWEEN 2 CATEGORICAL VARAIBLES
from scipy.stats import chi2_contingency

#creation of contingency table
contingency_table = pd.crosstab(df['Daily usages'], df['Performance impact'])

plt.figure(figsize=(10, 6))
sns.heatmap(contingency_table, annot=True, cmap="YlGnBu")
plt.title('Contingency Table: Daily Usage vs Performance Impact')
plt.ylabel('Daily Usage')
plt.xlabel('Performance Impact')
plt.show()

# %%
## How does the frequency of symptoms relate to the health rating given by participants?

contingency_table = pd.crosstab(df['Symptom frequency'], df['Health rating'])

plt.figure(figsize=(10, 6))
sns.heatmap(contingency_table, annot=True, cmap="YlGnBu", fmt="d")
plt.title('Symptom Frequency vs Health Rating')
plt.ylabel('Symptom Frequency')
plt.xlabel('Health Rating')
plt.show()

# %%
## Are there any trends in mobile phone usage patterns based on the operating system?
contingency_table = pd.crosstab(df['Daily usages'], df['Mobile Operating System'])

plt.figure(figsize=(10, 6))
sns.heatmap(contingency_table, annot=True, cmap="YlGnBu", fmt="d")
# Out:
# <Axes: xlabel='Mobile Operating System', ylabel='Daily usages'>
